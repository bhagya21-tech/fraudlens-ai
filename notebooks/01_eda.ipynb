# %% [markdown]
# Cell 1
# -

# %%
import os
print(os.getcwd())
print(os.listdir())
print(os.path.exists("data/fake_real_job_postings.csv"))
print(os.path.exists("../data/fake_real_job_postings.csv"))
# Out:
# c:\Users\Trinetra\3D Objects\fake-job-posting-detection\notebooks
# ['01_eda.ipynb', '02_preprocessing.ipynb']
# False
# False

# %%
import os

print("Parent Folder:")
print(os.listdir(".."))
print("Data Folder Exists:", os.path.exists("../data"))
# Out:
# Parent Folder:
# ['app.py', 'data', 'models', 'notebooks', 'README.md', 'requirements.txt', 'src']
# Data Folder Exists: True

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Trinetra\3D Objects\fake-job-posting-detection\data\fake_real_job_postings.csv.csv")


df.head()
# Out:
#    job_id                    job_title  \
# 0       1            Software Engineer
# 1       2               Content Writer
# 2       3  Customer Support Specialist
# 3       4                 Data Analyst
# 4       5             Graphic Designer
#
#                                      job_description  \
# 0  We are looking for responsibilities fast-paced...
# 1  We are looking for required support experience...
# 2  We are looking for dynamic required fast-paced...
# 3  We are looking for collaboration skills suppor...
# 4  We are looking for team growth growth fast-pac...
#
#                                         requirements  \
# 0  Candidates should have dynamic team skills fas...
# 1  Candidates should have required team fast-pace...
# 2  Candidates should have preferred knowledge opp...
# 3  Candidates should have innovation team require...
# 4  Candidates should have experience preferred kn...
#
#                                             benefits company_name  \
# ...

# %% [markdown]
# Cell 2
# -

# %%
print(df.shape)
# Out:
# (3000, 25)

# %% [markdown]
# Cell 3
# -

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   job_id                     3000 non-null   int64
#  1   job_title                  3000 non-null   object
#  2   job_description            3000 non-null   object
#  3   requirements               3000 non-null   object
#  4   benefits                   3000 non-null   object
#  5   company_name               1528 non-null   object
#  6   company_profile            3000 non-null   object
#  7   industry                   3000 non-null   object
#  8   employment_type            3000 non-null   object
#  9   location                   3000 non-null   object
#  10  salary_range               3000 non-null   object
#  11  required_experience_years  3000 non-null   int64
#  12  education_level            3000 non-null   object
# ...

# %% [markdown]
# Cell 4
# -

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# fraud_reason                 1528
# company_website              1472
# company_name                 1472
# job_id                          0
# job_title                       0
# benefits                        0
# company_profile                 0
# requirements                    0
# job_description                 0
# employment_type                 0
# industry                        0
# location                        0
# salary_range                    0
# department                      0
# posting_date                    0
# required_experience_years       0
# education_level                 0
# contact_email                   0
# application_deadline            0
# num_open_positions              0
# has_logo                        0
# job_function                    0
# telecommuting                   0
# text_length                     0
# is_fake                         0
# dtype: int64

# %% [markdown]
# Cell 5
# -

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))

sns.countplot(
    x='is_fake',
    data=df
)

plt.title("Fake vs Real Jobs")

plt.show()

# %% [markdown]
# Cell 6

# %%
df['is_fake'].value_counts(normalize=True)*100
# Out:
# is_fake
# 0    50.933333
# 1    49.066667
# Name: proportion, dtype: float64

# %% [markdown]
# Cell 7
# -

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['text_length'],
    bins=30
)

plt.show()

# %% [markdown]
# Cell 8
# -

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.show()
